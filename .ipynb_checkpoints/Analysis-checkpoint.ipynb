# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv("weatherAUS.csv")

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df["Sunshine"]=df["Sunshine"].fillna(0)

# %%
df['Location'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
cloudat9=df['Cloud9am'].value_counts()
cloudat9
# Out:
# 7.0    19972
# 1.0    15687
# 8.0    14697
# 0.0     8642
# 6.0     8171
# 2.0     6500
# 3.0     5914
# 5.0     5567
# 4.0     4420
# 9.0        2
# Name: Cloud9am, dtype: int64

# %%
# df=df.dropna(subset=['RainTomorrow','RainToday','Temp3pm', 'Temp9am'])

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.isnull().sum()*100/145460
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine          0.000000
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
df=df.drop('Evaporation', axis=1)

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in df.columns if feature not in numerical_feature]

print(numerical_feature)
print(discrete_feature)
print(continuous_feature)
print(categorical_feature)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
# ['Cloud9am', 'Cloud3pm']
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
# ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
sns.set_style('whitegrid')
sns.countplot(x='Cloud9am',hue='RainToday',data=df,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Cloud9am', ylabel='count'>

# %%
for i in numerical_feature:
    plt.figure(figsize=(12, 7))
    sns.boxplot(x='RainToday',y=df[i],data=df,palette='winter')

# %%
# df.head()

# %%
df['Cloud9am'].value_counts()
# Out:
# 7.0    19972
# 1.0    15687
# 8.0    14697
# 0.0     8642
# 6.0     8171
# 2.0     6500
# 3.0     5914
# 5.0     5567
# 4.0     4420
# 9.0        2
# Name: Cloud9am, dtype: int64

# %% [markdown]
# ## Replacing with mode

# %%
mode=df['Cloud9am'].mode()
print(mode[0])
# Out:
# 7.0

# %%
df['Cloud9am']=df['Cloud9am'].fillna(mode[0])

# %%
df['Cloud9am'].isnull().sum()
# Out:
# 0

# %%
# df.head()

# %%
mode=df['Cloud3pm'].mode()
mode
# Out:
# 0    7.0
# Name: Cloud3pm, dtype: float64

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
# sns.countplot(x='Cloud3pm',hue=categorical_feature[2],data=df,palette='RdBu_r')

# %%
# sns.countplot(x='Cloud3pm',hue=categorical_feature[4],data=df,palette='RdBu_r')

# %%
# new_df=df[['WindDir3pm','Cloud3pm']]
# new_df=new_df.dropna()
# # new_df.head()
# new_df[new_df['WindDir3pm']=='NE']['Cloud3pm'].median()

# %%
# # new_df=df[['WindDir3pm','Cloud3pm']]
# x=new_df['WindDir3pm'].unique()
# # x
# # print(df['Cloud3pm']).isnull().sum()
# for i in x:
#     print(df['Cloud3pm'].isnull().sum())
#     new_df=df[['WindDir3pm','Cloud3pm']]
#     new_df=new_df.dropna()
#     median=new_df[new_df['WindDir3pm']=='NE']['Cloud3pm'].median()
#     df['Cloud3pm']=df[df['WindDir3pm']==i]['Cloud3pm'].fillna(median[0])
# # df[df['WindDir3pm']=='N']['Cloud3pm']
# # df['Cloud3pm'].isnull().sum()
# # df.head()

# %%
df['Cloud3pm'].value_counts()
# Out:
# 7.0    18229
# 1.0    14976
# 8.0    12660
# 6.0     8978
# 2.0     7226
# 3.0     6921
# 5.0     6815
# 4.0     5322
# 0.0     4974
# 9.0        1
# Name: Cloud3pm, dtype: int64

# %%
df['Cloud3pm']=df['Cloud3pm'].fillna(mode[0])

# %%
# df.head()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## replacing with mean

# %%
mean=df['Pressure9am'].mean()
mean
# Out:
# 1017.6499397983052

# %%
df['Pressure9am'].median()
# Out:
# 1017.6

# %%
df['Pressure9am'].mode()
# Out:
# 0    1016.4
# Name: Pressure9am, dtype: float64

# %%
# df['Pressure9am']=df['Pressure9am'].fillna(mean)

# %%
df['Pressure9am'].isnull().sum()
# Out:
# 15065

# %%
# df.head()

# %%
mean=df['Pressure3pm'].mean()
mean

def impute_var(df,var):
    mean=df[var].mean()
    mode=df[var].mode()
    median=df[var].median()
    df[var+"_mean"]=df[var].fillna(mean)
    df[var+"_median"]=df[var].fillna(median)
    df[var+"_mode"]=df[var].fillna(mode[0])
    
    df[var+"_random"]=df[var]
    
    random_sample=df[var].dropna().sample(df[var].isnull().sum(),random_state=0)
    random_sample.index=df[df[var].isnull()].index
    df.loc[df[var].isnull(),var+'_random']=random_sample
    
impute_var(df,"Pressure3pm")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Pressure3pm'].plot(kind='kde', ax=ax)
df.Pressure3pm_mean.plot(kind='kde', ax=ax, color='red')
df.Pressure3pm_median.plot(kind='kde', ax=ax, color='yellow')
df.Pressure3pm_random.plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  \
# 0  01-12-2008   Albury     13.4     22.9       0.6       0.0           W
# 1  02-12-2008   Albury      7.4     25.1       0.0       0.0         WNW
# 2  03-12-2008   Albury     12.9     25.7       0.0       0.0         WSW
# 3  04-12-2008   Albury      9.2     28.0       0.0       0.0          NE
# 4  05-12-2008   Albury     17.5     32.3       1.0       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Cloud9am  Cloud3pm  Temp9am  \
# 0           44.0          W        WNW  ...       8.0       7.0     16.9
# 1           44.0        NNW        WSW  ...       7.0       7.0     17.2
# 2           46.0          W        WSW  ...       7.0       2.0     21.0
# 3           24.0         SE          E  ...       7.0       7.0     18.1
# 4           41.0        ENE         NW  ...       7.0       8.0     17.8
#
#    Temp3pm  RainToday  RainTomorrow  Pressure3pm_mean  Pressure3pm_median  \
# ...

# %%
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm_random'])
df=df.drop(["Pressure3pm_random","Pressure3pm_mean","Pressure3pm_median","Pressure3pm_mode"],axis=1)

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  \
# 0  01-12-2008   Albury     13.4     22.9       0.6       0.0           W
# 1  02-12-2008   Albury      7.4     25.1       0.0       0.0         WNW
# 2  03-12-2008   Albury     12.9     25.7       0.0       0.0         WSW
# 3  04-12-2008   Albury      9.2     28.0       0.0       0.0          NE
# 4  05-12-2008   Albury     17.5     32.3       1.0       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           44.0          W        WNW  ...         71.0         22.0
# 1           44.0        NNW        WSW  ...         44.0         25.0
# 2           46.0          W        WSW  ...         38.0         30.0
# 3           24.0         SE          E  ...         45.0         16.0
# 4           41.0        ENE         NW  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
mode=df['WindGustDir'].mode()
mode
# Out:
# 0    W
# Name: WindGustDir, dtype: object

# %%
df.WindGustDir.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df['WindGustDir']=df['WindGustDir'].fillna(mode[0])

# %%
# df.head()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
df["Rainfall"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111)
# df['Rainfall'].plot(kind='kde', ax=ax)
# lines, labels = ax.get_legend_handles_labels()
# ax.legend(lines, labels, loc='best')

# %%
meanRain=df["Rainfall"].mean()
df['Rainfall']=df["Rainfall"].fillna(mean)

# %%
df['WindDir9am'].isnull().sum()
# Out:
# 10566

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall             0
# Sunshine             0
# WindGustDir          0
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df['WindDir9am'].value_counts()
# Out:
# N      11758
# SE      9287
# E       9176
# SSE     9112
# NW      8749
# S       8659
# W       8459
# SW      8423
# NNE     8129
# NNW     7980
# ENE     7836
# NE      7671
# ESE     7630
# SSW     7587
# WNW     7414
# WSW     7024
# Name: WindDir9am, dtype: int64

# %%
df['WindDir9am']=df['WindDir9am'].fillna('E')

# %%
df['WindDir9am'].isnull().sum()
# Out:
# 0

# %%
mean=df['WindGustSpeed'].mean()
mean
# Out:
# 40.03523007167319

# %%
df['WindGustSpeed'].std()
# Out:
# 13.607062267381362

# %%
df['WindGustSpeed']=df['WindGustSpeed'].fillna(mean)

# %%
df['WindGustSpeed'].std()
# Out:
# 13.11825276217344

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(22,16))
# Out:
# array([[<AxesSubplot:xlabel='MinTemp', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='MaxTemp', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Rainfall', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Sunshine', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='WindGustSpeed', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='WindSpeed9am', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='WindSpeed3pm', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Humidity9am', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Humidity3pm', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Pressure9am', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Pressure3pm', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Cloud9am', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Cloud3pm', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Temp9am', ylabel='MinTemp'>,
#         <AxesSubplot:xlabel='Temp3pm', ylabel='MinTemp'>],
#        [<AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>,
# ...

# %%
# df=df.dropna(axis=1)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall             0
# Sunshine             0
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am           0
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
impute_var(df,"Pressure9am")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  \
# 0  01-12-2008   Albury     13.4     22.9       0.6       0.0           W
# 1  02-12-2008   Albury      7.4     25.1       0.0       0.0         WNW
# 2  03-12-2008   Albury     12.9     25.7       0.0       0.0         WSW
# 3  04-12-2008   Albury      9.2     28.0       0.0       0.0          NE
# 4  05-12-2008   Albury     17.5     32.3       1.0       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Cloud9am  Cloud3pm  Temp9am  \
# 0           44.0          W        WNW  ...       8.0       7.0     16.9
# 1           44.0        NNW        WSW  ...       7.0       7.0     17.2
# 2           46.0          W        WSW  ...       7.0       2.0     21.0
# 3           24.0         SE          E  ...       7.0       7.0     18.1
# 4           41.0        ENE         NW  ...       7.0       8.0     17.8
#
#    Temp3pm  RainToday  RainTomorrow  Pressure9am_mean  Pressure9am_median  \
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Pressure9am'].plot(kind='kde', ax=ax)
df.Pressure9am_mean.plot(kind='kde', ax=ax, color='red')
df.Pressure9am_median.plot(kind='kde', ax=ax, color='yellow')
df.Pressure9am_random.plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Pressure9am'].plot(kind='kde', ax=ax)
df.Pressure9am_mean.plot(kind='kde', ax=ax, color='red')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Pressure9am']=df['Pressure9am_random']

# %%
df=df.drop(['Pressure9am_random','Pressure9am_mean','Pressure9am_mode','Pressure9am_median'],axis=1)

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  \
# 0  01-12-2008   Albury     13.4     22.9       0.6       0.0           W
# 1  02-12-2008   Albury      7.4     25.1       0.0       0.0         WNW
# 2  03-12-2008   Albury     12.9     25.7       0.0       0.0         WSW
# 3  04-12-2008   Albury      9.2     28.0       0.0       0.0          NE
# 4  05-12-2008   Albury     17.5     32.3       1.0       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           44.0          W        WNW  ...         71.0         22.0
# 1           44.0        NNW        WSW  ...         44.0         25.0
# 2           46.0          W        WSW  ...         38.0         30.0
# 3           24.0         SE          E  ...         45.0         16.0
# 4           41.0        ENE         NW  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
for feature in categorical_feature:
    mode=df[feature].mode()
    df[feature]=df[feature].fillna(mode[0])

# %%
# df["WindDir3pm"]=df["WindDir3pm"].fillna(mode)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
mean3pm=df["Temp3pm"].mean()
mean9am=df["Temp9am"].mean()

df["Temp3pm"]=df["Temp3pm"].fillna(mean3pm)
df["Temp9am"]=df["Temp9am"].fillna(mean9am)

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp          1485
# MaxTemp          1261
# Rainfall            0
# Sunshine            0
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am     1767
# WindSpeed3pm     3062
# Humidity9am      2654
# Humidity3pm      4507
# Pressure9am         0
# Pressure3pm         0
# Cloud9am            0
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday           0
# RainTomorrow        0
# dtype: int64

# %%
df.plot(kind="scatter",x="WindSpeed9am",y="WindSpeed3pm",alpha=0.6)
# Out:
# <AxesSubplot:xlabel='WindSpeed9am', ylabel='WindSpeed3pm'>

# %%
df.plot(kind="scatter",x="Humidity9am",y="Humidity3pm",alpha=0.6)
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Humidity3pm'>

# %%
corr_mat=df.corr()
corr_mat['WindSpeed3pm'].sort_values(ascending=False)
# Out:
# WindSpeed3pm     1.000000
# WindGustSpeed    0.658307
# WindSpeed9am     0.519547
# MinTemp          0.175173
# Temp9am          0.162230
# Sunshine         0.104499
# MaxTemp          0.050300
# Temp3pm          0.027664
# Rainfall         0.024177
# Humidity3pm      0.016432
# Cloud9am        -0.003815
# Cloud3pm        -0.024162
# Humidity9am     -0.145525
# Pressure3pm     -0.229618
# Pressure9am     -0.267022
# Name: WindSpeed3pm, dtype: float64

# %%
meanWind3=df["WindSpeed3pm"].mean()
meanWind9=df["WindSpeed9am"].mean()
meanHumidity3=df["Humidity3pm"].mean()
meanHumidity9=df["Humidity9am"].mean()

# %%
df["WindSpeed3pm"]=df["WindSpeed3pm"].fillna(meanWind3)
df["WindSpeed9am"]=df["WindSpeed9am"].fillna(meanWind9)
df["Humidity3pm"]=df["Humidity3pm"].fillna(meanHumidity3)
df["Humidity9am"]=df["Humidity9am"].fillna(meanHumidity9)
df["MaxTemp"]=df["MaxTemp"].fillna(df["MaxTemp"].median())
df["MinTemp"]=df["MinTemp"].fillna(df["MinTemp"].median())

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
train_df=df.drop(["Date","Location","RainTomorrow"],axis=1)

# %%
x=train_df.drop("RainTomorrow",axis=1)
# x=train_df
y=df["RainTomorrow"]

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
train_df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6       0.0           W           44.0          W
# 1      7.4     25.1       0.0       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0       0.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
conf=confusion_matrix(y_test,predictions)

# %%
conf
# Out:
# array([[21736,   959],
#        [ 3314,  3083]], dtype=int64)

# %%
ascore=accuracy_score(y_test,predictions)
ascore
# Out:
# 0.8531211329575141
